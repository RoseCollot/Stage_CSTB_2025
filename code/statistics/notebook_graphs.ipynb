# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np
import scipy
from scipy import stats
import gffutils
from Bio import Phylo
import matplotlib.pyplot as plt

# %%
#update table : new genome accession id --> old one (currently used) 
df_species = pd.read_csv('/home/collot/stage/collot/PrimateData/PrimateInfo.csv',sep='\t')
df_species = df_species.sort_values(by='Assembly Accession')
df_species['Assembly Accession'] = df_species['Assembly Accession'].replace('GCF_043159975.1', 'GCF_000956065.1')
pd.DataFrame.to_csv(df_species,'/home/collot/stage/collot/collot/out_stats/df_species.tsv',sep='\t')

# %%
def create_table (df_species,path_to_df_dir, path_to_output) : 
    """create a table with statistics for each specie"""
    list_species = []
    for index, row in df_species.iterrows(): 
        path_dir= os.path.join(path_to_df_dir,row['Assembly Accession'])
        df = pd.read_csv(os.path.join(path_dir,'df'))
        df_exons = pd.read_csv(os.path.join(path_dir,'df_exons'))
        df_introns = pd.read_csv(os.path.join(path_dir,'df_introns'))
        df_stats = pd.read_csv(os.path.join(path_dir,'df_stats'))
        specie = []
        specie.append(row['Organism Name'])
        specie.append(row['Assembly Accession'])
        genes_mean_length = np.mean(df_stats['length'])
        specie.append(genes_mean_length)
        nb_genes = len(df['gene'].unique())
        specie.append(nb_genes)        
        nb_trancripts = len(df['transcript'].unique())
        specie.append(nb_trancripts)        
        nb_exons = len(df_exons)
        specie.append(nb_exons) 
        exons_mean_length = np.mean(df_exons['length'])       
        specie.append(exons_mean_length)
        exon_ratio = np.mean(df_stats['ratio_exons'])        
        specie.append(exon_ratio) 
        nb_introns = len(df_introns)
        specie.append(nb_introns)  
        intron_mean_length = np.mean(df_introns['length']) 
        specie.append(intron_mean_length)             
        intron_ratio = np.mean(df_stats['ratio_introns'])
        specie.append(intron_ratio)
        list_species.append(specie)
    table_species = pd.DataFrame(list_species, 
                                 columns=('specie_name','genome_id','genes_mean_length','nb_genes','nb_transcripts','nb_exons','exons_mean_length','exon_ratio','nb_introns','introns_mean_length','intron_ratio'))
    table_species = table_species.sort_values(by='genome_id')
    table_species.to_csv(path_to_output)
    return table_species

df_table=create_table(df_species,'/home/collot/stage/collot/collot/out_stats/output_dataframes', '/home/collot/stage/collot/collot/out_stats/table_species.csv')
print(df_table)
# Out:
#                         specie_name         genome_id  genes_mean_length  \
# 0                      Homo sapiens  GCF_000001405.40       59033.034256
# 1                  Carlito syrichta   GCF_000164805.1       41794.334183
# 2                Microcebus murinus   GCF_000165445.2       53891.736750
# 3                Otolemur garnettii   GCF_000181295.1       49881.267563
# 4      Colobus angolensis palliatus   GCF_000951035.1       57209.445754
# 5            Mandrillus leucophaeus   GCF_000951045.1       56736.680219
# 6                   Cercocebus atys   GCF_000955945.1       59925.895896
# 34                Macaca nemestrina   GCF_000956065.1       61083.381596
# 7             Propithecus coquereli   GCF_000956105.1       48496.640520
# 8                    Cebus imitator   GCF_001604975.1       52930.644031
# 9               Rhinopithecus bieti   GCF_001698545.2       50687.277999
# 10        Piliocolobus tephrosceles   GCF_002776525.5       54651.673309
# 11             Theropithecus gelada   GCF_003255815.1       57570.411756
# 12                   Macaca mulatta   GCF_003339765.1       58467.782009
# 13              Nomascus leucogenys   GCF_006542625.1       58303.141416
# 14          Rhinopithecus roxellana   GCF_007565055.1       56637.755182
# 15                     Papio anubis   GCF_008728515.1       58406.217241
# 16                   Sapajus apella   GCF_009761245.1       56713.570220
# 17         Trachypithecus francoisi   GCF_009764315.1       55277.981234
# 18                 Hylobates moloch   GCF_009828535.3       57366.781438
# 19               Callithrix jacchus   GCF_011100555.1       58085.377097
# 20              Chlorocebus sabaeus   GCF_015252025.1       55445.058511
# 21  Saimiri boliviensis boliviensis   GCF_016699345.2       53802.852675
# 22                      Lemur catta   GCF_020740605.2       45018.493417
# 23       Macaca thibetana thibetana   GCF_024542745.1       88108.147696
# 24               Nycticebus coucang   GCF_027406575.1       54150.642951
# 25                  Pan troglodytes   GCF_028858775.2       59681.030448
# 26         Symphalangus syndactylus   GCF_028878055.3       60175.529092
# 27                   Pongo pygmaeus   GCF_028885625.2       58014.607524
# 28                     Pongo abelii   GCF_028885655.2       58090.492317
# 29          Gorilla gorilla gorilla   GCF_029281585.2       57366.657994
# 30                     Pan paniscus   GCF_029289425.2       59088.669011
# 31                  Aotus nancymaae   GCF_030222135.1       56501.649591
# 32              Macaca fascicularis   GCF_037993035.1       59024.330583
# 33                Eulemur rufifrons   GCF_041146395.1       46107.496157
#
#     nb_genes  nb_transcripts  nb_exons  exons_mean_length  exon_ratio  \
# 0      23295           89100    263971         412.473226    0.306909
# 1      20004           30638    193818         227.282770    0.251326
# 2      20509           51633    221819         310.295881    0.281555
# 3      19558           30386    197441         239.951550    0.259868
# 4      20103           35756    207806         271.333142    0.257309
# 5      20267           35562    208608         270.517890    0.245738
# 6      20614           55326    222530         341.257660    0.281410
# 34     21017           57146    225883         332.536043    0.280391
# 7      19378           26940    191813         231.305720    0.252280
# 8      21544           47739    213867         302.378436    0.308138
# 9      21644           44069    216581         287.000042    0.285981
# 10     21528           46545    216449         305.634902    0.288070
# 11     20670           45648    213876         299.422086    0.295238
# 12     21111           57714    225843         329.035268    0.298190
# 13     20514           44728    216452         315.684078    0.274217
# 14     21081           47177    219453         301.678095    0.284556
# 15     21078           60662    225920         370.615669    0.304459
# 16     20564           52711    216053         324.305004    0.293506
# 17     21688           54953    221705         315.631082    0.315442
# 18     21733           51899    222642         313.052560    0.296076
# 19     22355           67453    233079         409.811678    0.345336
# 20     21620           52313    220553         340.797251    0.321870
# 21     20974           40190    211927         282.583106    0.296790
# 22     19977           40275    209927         272.167396    0.284492
# 23     21402           53815    199916         355.153474    0.293019
# 24     22137           49050    218094         312.606083    0.345265
# 25     22563           83185    240389         362.864678    0.323540
# 26     22102           72563    233288         358.004475    0.330686
# 27     22088           65062    233557         356.640293    0.312030
# 28     22193           65976    233039         370.957097    0.320734
# 29     22637           66155    235706         369.175129    0.319511
# 30     22895           65875    232951         472.294225    0.358817
# 31     21766           48938    225134         336.874737    0.320461
# 32     21813           57422    228443         400.494364    0.317038
# 33     19514           34991    203440         242.891786    0.280352
#
#     nb_introns  introns_mean_length  intron_ratio
# 0       241260          5108.335534      0.776065
# 1       173940          4536.146562      0.835010
# 2       201650          5078.070667      0.796917
# 3       178048          5202.132273      0.835623
# 4       187962          5780.122589      0.822484
# 5       188592          5757.999183      0.830206
# 6       202198          5661.834776      0.794230
# 34      205211          5793.996340      0.794132
# 7       172586          5181.562462      0.832695
# 8       192757          5535.382046      0.806435
# 9       195202          5261.540020      0.791192
# 10      195218          5649.031724      0.794096
# 11      193498          5783.574543      0.806828
# 12      205048          5605.124312      0.796882
# 13      196188          5699.364818      0.803389
# 14      198709          5627.718981      0.804844
# 15      205164          5523.797021      0.785067
# 16      195744          5554.050295      0.797798
# 17      200532          5566.857349      0.793314
# 18      201351          5757.380455      0.795089
# 19      211298          5596.034066      0.770335
# 20      199257          5589.814511      0.786304
# 21      191350          5556.089579      0.812630
# 22      190167          4404.915942      0.803150
# 23      181738          8495.292713      0.795760
# 24      196479          5682.081378      0.801608
# 25      218286          5654.792868      0.784038
# 26      211692          5786.079219      0.780021
# 27      211891          5586.433275      0.784908
# 28      211289          5596.219756      0.778820
# 29      213485          5603.361726      0.781530
# 30      210567          5790.728395      0.755735
# 31      203854          5598.088975      0.795677
# 32      207164          5693.283949      0.784945
# 33      184122          4595.138044      0.825488

# %%
tree = Phylo.read('/home/collot/stage_git/species_tree.nwk', format='newick')
taxa = []
for term in tree.get_terminals():
    taxa.append(term.name)
distance_df = pd.DataFrame(index = taxa, columns=taxa)
for i in taxa: 
    for j in taxa : 
        distance_df.loc[i][j]=tree.distance(i,j)
distance_df= distance_df.astype(float)
specie_order = distance_df.index.to_list()
specie_order[10] ='Saimiri_boliviensis_boliviensis'
specie_order = [name.replace('_', ' ') for name in specie_order]
print(specie_order)
print(distance_df)
sns.heatmap(distance_df, cmap='grey',xticklabels=True, yticklabels=True  )
# Out:
# /tmp/ipykernel_721288/888522806.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   distance_df.loc[i][j]=tree.distance(i,j)
# ['Nycticebus coucang', 'Otolemur garnettii', 'Propithecus coquereli', 'Microcebus murinus', 'Lemur catta', 'Eulemur rufifrons', 'Aotus nancymaae', 'Callithrix jacchus', 'Cebus imitator', 'Sapajus apella', 'Saimiri boliviensis boliviensis', 'Symphalangus syndactylus', 'Hylobates moloch', 'Nomascus leucogenys', 'Gorilla gorilla gorilla', 'Homo sapiens', 'Pan paniscus', 'Pan troglodytes', 'Pongo pygmaeus', 'Pongo abelii', 'Chlorocebus sabaeus', 'Papio anubis', 'Theropithecus gelada', 'Mandrillus leucophaeus', 'Cercocebus atys', 'Macaca thibetana thibetana', 'Macaca mulatta', 'Macaca fascicularis', 'Macaca nemestrina', 'Trachypithecus francoisi', 'Rhinopithecus roxellana', 'Rhinopithecus bieti', 'Piliocolobus tephrosceles', 'Colobus angolensis palliatus', 'Carlito syrichta']
#                               Nycticebus_coucang  Otolemur_garnettii  \
# Nycticebus_coucang                      0.000000           78.078600
# Otolemur_garnettii                     78.078600            0.000000
# Propithecus_coquereli                 118.600000          118.600000
# Microcebus_murinus                    118.600000          118.600000
# Lemur_catta                           118.600000          118.600000
# Eulemur_rufifrons                     118.600000          118.600000
# Aotus_nancymaae                       147.509840          147.509840
# Callithrix_jacchus                    147.509840          147.509840
# Cebus_imitator                        147.509840          147.509840
# Sapajus_apella                        147.509840          147.509840
# Saimiri_boliviensis                   147.406507          147.406507
# Symphalangus_syndactylus              147.509840          147.509840
# Hylobates_moloch                      147.509840          147.509840
# Nomascus_leucogenys                   147.509840          147.509840
# Gorilla_gorilla_gorilla               147.509840          147.509840
# Homo_sapiens                          147.509840          147.509840
# Pan_paniscus                          147.509840          147.509840
# Pan_troglodytes                       147.479487          147.479487
# Pongo_pygmaeus                        147.509840          147.509840
# Pongo_abelii                          147.509840          147.509840
# Chlorocebus_sabaeus                   147.509840          147.509840
# Papio_anubis                          147.509840          147.509840
# Theropithecus_gelada                  147.509840          147.509840
# Mandrillus_leucophaeus                147.509840          147.509840
# Cercocebus_atys                       147.509840          147.509840
# Macaca_thibetana_thibetana            147.509840          147.509840
# Macaca_mulatta                        147.509840          147.509840
# Macaca_fascicularis                   147.509840          147.509840
# Macaca_nemestrina                     147.509840          147.509840
# Trachypithecus_francoisi              147.509840          147.509840
# Rhinopithecus_roxellana               147.509840          147.509840
# Rhinopithecus_bieti                   147.509840          147.509840
# Piliocolobus_tephrosceles             147.509840          147.509840
# Colobus_angolensis_palliatus          147.509840          147.509840
# Carlito_syrichta                      147.509840          147.509840
#
#                               Propithecus_coquereli  Microcebus_murinus  \
# Nycticebus_coucang                       118.600000          118.600000
# Otolemur_garnettii                       118.600000          118.600000
# Propithecus_coquereli                      0.000000           71.880000
# Microcebus_murinus                        71.880000            0.000000
# Lemur_catta                               72.000000           72.000000
# Eulemur_rufifrons                         72.000000           72.000000
# Aotus_nancymaae                          147.509840          147.509840
# Callithrix_jacchus                       147.509840          147.509840
# Cebus_imitator                           147.509840          147.509840
# Sapajus_apella                           147.509840          147.509840
# Saimiri_boliviensis                      147.406507          147.406507
# Symphalangus_syndactylus                 147.509840          147.509840
# Hylobates_moloch                         147.509840          147.509840
# Nomascus_leucogenys                      147.509840          147.509840
# Gorilla_gorilla_gorilla                  147.509840          147.509840
# Homo_sapiens                             147.509840          147.509840
# Pan_paniscus                             147.509840          147.509840
# Pan_troglodytes                          147.479487          147.479487
# Pongo_pygmaeus                           147.509840          147.509840
# Pongo_abelii                             147.509840          147.509840
# Chlorocebus_sabaeus                      147.509840          147.509840
# Papio_anubis                             147.509840          147.509840
# Theropithecus_gelada                     147.509840          147.509840
# Mandrillus_leucophaeus                   147.509840          147.509840
# Cercocebus_atys                          147.509840          147.509840
# Macaca_thibetana_thibetana               147.509840          147.509840
# Macaca_mulatta                           147.509840          147.509840
# Macaca_fascicularis                      147.509840          147.509840
# Macaca_nemestrina                        147.509840          147.509840
# Trachypithecus_francoisi                 147.509840          147.509840
# Rhinopithecus_roxellana                  147.509840          147.509840
# Rhinopithecus_bieti                      147.509840          147.509840
# Piliocolobus_tephrosceles                147.509840          147.509840
# Colobus_angolensis_palliatus             147.509840          147.509840
# Carlito_syrichta                         147.509840          147.509840
#
#                               Lemur_catta  Eulemur_rufifrons  Aotus_nancymaae  \
# Nycticebus_coucang             118.600000         118.600000       147.509840
# Otolemur_garnettii             118.600000         118.600000       147.509840
# Propithecus_coquereli           72.000000          72.000000       147.509840
# Microcebus_murinus              72.000000          72.000000       147.509840
# Lemur_catta                      0.000000          39.460000       147.509840
# Eulemur_rufifrons               39.460000           0.000000       147.509840
# Aotus_nancymaae                147.509840         147.509840         0.000000
# Callithrix_jacchus             147.509840         147.509840        32.800000
# Cebus_imitator                 147.509840         147.509840        35.766960
# Sapajus_apella                 147.509840         147.509840        35.766960
# Saimiri_boliviensis            147.406507         147.406507        35.663627
# Symphalangus_syndactylus       147.509840         147.509840        85.800000
# Hylobates_moloch               147.509840         147.509840        85.800000
# Nomascus_leucogenys            147.509840         147.509840        85.800000
# Gorilla_gorilla_gorilla        147.509840         147.509840        85.800000
# Homo_sapiens                   147.509840         147.509840        85.800000
# Pan_paniscus                   147.509840         147.509840        85.800000
# Pan_troglodytes                147.479487         147.479487        85.769647
# Pongo_pygmaeus                 147.509840         147.509840        85.800000
# Pongo_abelii                   147.509840         147.509840        85.800000
# Chlorocebus_sabaeus            147.509840         147.509840        85.800000
# Papio_anubis                   147.509840         147.509840        85.800000
# Theropithecus_gelada           147.509840         147.509840        85.800000
# Mandrillus_leucophaeus         147.509840         147.509840        85.800000
# Cercocebus_atys                147.509840         147.509840        85.800000
# Macaca_thibetana_thibetana     147.509840         147.509840        85.800000
# Macaca_mulatta                 147.509840         147.509840        85.800000
# Macaca_fascicularis            147.509840         147.509840        85.800000
# Macaca_nemestrina              147.509840         147.509840        85.800000
# Trachypithecus_francoisi       147.509840         147.509840        85.800000
# Rhinopithecus_roxellana        147.509840         147.509840        85.800000
# Rhinopithecus_bieti            147.509840         147.509840        85.800000
# Piliocolobus_tephrosceles      147.509840         147.509840        85.800000
# Colobus_angolensis_palliatus   147.509840         147.509840        85.800000
# Carlito_syrichta               147.509840         147.509840       137.200000
#
#                               Callithrix_jacchus  Cebus_imitator  \
# Nycticebus_coucang                    147.509840      147.509840
# Otolemur_garnettii                    147.509840      147.509840
# Propithecus_coquereli                 147.509840      147.509840
# Microcebus_murinus                    147.509840      147.509840
# Lemur_catta                           147.509840      147.509840
# Eulemur_rufifrons                     147.509840      147.509840
# Aotus_nancymaae                        32.800000       35.766960
# Callithrix_jacchus                      0.000000       35.766960
# Cebus_imitator                         35.766960        0.000000
# Sapajus_apella                         35.766960       12.360000
# Saimiri_boliviensis                    35.663627       30.696667
# Symphalangus_syndactylus               85.800000       85.800000
# Hylobates_moloch                       85.800000       85.800000
# Nomascus_leucogenys                    85.800000       85.800000
# Gorilla_gorilla_gorilla                85.800000       85.800000
# Homo_sapiens                           85.800000       85.800000
# Pan_paniscus                           85.800000       85.800000
# Pan_troglodytes                        85.769647       85.769647
# Pongo_pygmaeus                         85.800000       85.800000
# Pongo_abelii                           85.800000       85.800000
# Chlorocebus_sabaeus                    85.800000       85.800000
# Papio_anubis                           85.800000       85.800000
# Theropithecus_gelada                   85.800000       85.800000
# Mandrillus_leucophaeus                 85.800000       85.800000
# Cercocebus_atys                        85.800000       85.800000
# Macaca_thibetana_thibetana             85.800000       85.800000
# Macaca_mulatta                         85.800000       85.800000
# Macaca_fascicularis                    85.800000       85.800000
# Macaca_nemestrina                      85.800000       85.800000
# Trachypithecus_francoisi               85.800000       85.800000
# Rhinopithecus_roxellana                85.800000       85.800000
# Rhinopithecus_bieti                    85.800000       85.800000
# Piliocolobus_tephrosceles              85.800000       85.800000
# Colobus_angolensis_palliatus           85.800000       85.800000
# Carlito_syrichta                      137.200000      137.200000
#
#                               Sapajus_apella  ...  Macaca_thibetana_thibetana  \
# Nycticebus_coucang                147.509840  ...                  147.509840
# Otolemur_garnettii                147.509840  ...                  147.509840
# Propithecus_coquereli             147.509840  ...                  147.509840
# Microcebus_murinus                147.509840  ...                  147.509840
# Lemur_catta                       147.509840  ...                  147.509840
# Eulemur_rufifrons                 147.509840  ...                  147.509840
# Aotus_nancymaae                    35.766960  ...                   85.800000
# Callithrix_jacchus                 35.766960  ...                   85.800000
# Cebus_imitator                     12.360000  ...                   85.800000
# Sapajus_apella                      0.000000  ...                   85.800000
# Saimiri_boliviensis                30.696667  ...                   85.696667
# Symphalangus_syndactylus           85.800000  ...                   57.640000
# Hylobates_moloch                   85.800000  ...                   57.640000
# Nomascus_leucogenys                85.800000  ...                   57.640000
# Gorilla_gorilla_gorilla            85.800000  ...                   57.640000
# Homo_sapiens                       85.800000  ...                   57.640000
# Pan_paniscus                       85.800000  ...                   57.640000
# Pan_troglodytes                    85.769647  ...                   57.609647
# Pongo_pygmaeus                     85.800000  ...                   57.640000
# Pongo_abelii                       85.800000  ...                   57.640000
# Chlorocebus_sabaeus                85.800000  ...                   24.654320
# Papio_anubis                       85.800000  ...                   20.908000
# Theropithecus_gelada               85.800000  ...                   20.908000
# Mandrillus_leucophaeus             85.800000  ...                   20.908000
# Cercocebus_atys                    85.800000  ...                   20.908000
# Macaca_thibetana_thibetana         85.800000  ...                    0.000000
# Macaca_mulatta                     85.800000  ...                    8.416840
# Macaca_fascicularis                85.800000  ...                    8.416840
# Macaca_nemestrina                  85.800000  ...                    8.994440
# Trachypithecus_francoisi           85.800000  ...                   35.510000
# Rhinopithecus_roxellana            85.800000  ...                   35.510000
# Rhinopithecus_bieti                85.800000  ...                   35.510000
# Piliocolobus_tephrosceles          85.800000  ...                   35.510000
# Colobus_angolensis_palliatus       85.800000  ...                   35.510000
# Carlito_syrichta                  137.200000  ...                  137.200000
#
#                               Macaca_mulatta  Macaca_fascicularis  \
# Nycticebus_coucang                147.509840           147.509840
# Otolemur_garnettii                147.509840           147.509840
# Propithecus_coquereli             147.509840           147.509840
# Microcebus_murinus                147.509840           147.509840
# Lemur_catta                       147.509840           147.509840
# Eulemur_rufifrons                 147.509840           147.509840
# Aotus_nancymaae                    85.800000            85.800000
# Callithrix_jacchus                 85.800000            85.800000
# Cebus_imitator                     85.800000            85.800000
# Sapajus_apella                     85.800000            85.800000
# Saimiri_boliviensis                85.696667            85.696667
# Symphalangus_syndactylus           57.640000            57.640000
# Hylobates_moloch                   57.640000            57.640000
# Nomascus_leucogenys                57.640000            57.640000
# Gorilla_gorilla_gorilla            57.640000            57.640000
# Homo_sapiens                       57.640000            57.640000
# Pan_paniscus                       57.640000            57.640000
# Pan_troglodytes                    57.609647            57.609647
# Pongo_pygmaeus                     57.640000            57.640000
# Pongo_abelii                       57.640000            57.640000
# Chlorocebus_sabaeus                24.654320            24.654320
# Papio_anubis                       20.908000            20.908000
# Theropithecus_gelada               20.908000            20.908000
# Mandrillus_leucophaeus             20.908000            20.908000
# Cercocebus_atys                    20.908000            20.908000
# Macaca_thibetana_thibetana          8.416840             8.416840
# Macaca_mulatta                      0.000000             6.634820
# Macaca_fascicularis                 6.634820             0.000000
# Macaca_nemestrina                   8.994440             8.994440
# Trachypithecus_francoisi           35.510000            35.510000
# Rhinopithecus_roxellana            35.510000            35.510000
# Rhinopithecus_bieti                35.510000            35.510000
# Piliocolobus_tephrosceles          35.510000            35.510000
# Colobus_angolensis_palliatus       35.510000            35.510000
# Carlito_syrichta                  137.200000           137.200000
#
#                               Macaca_nemestrina  Trachypithecus_francoisi  \
# Nycticebus_coucang                   147.509840                147.509840
# Otolemur_garnettii                   147.509840                147.509840
# Propithecus_coquereli                147.509840                147.509840
# Microcebus_murinus                   147.509840                147.509840
# Lemur_catta                          147.509840                147.509840
# Eulemur_rufifrons                    147.509840                147.509840
# Aotus_nancymaae                       85.800000                 85.800000
# Callithrix_jacchus                    85.800000                 85.800000
# Cebus_imitator                        85.800000                 85.800000
# Sapajus_apella                        85.800000                 85.800000
# Saimiri_boliviensis                   85.696667                 85.696667
# Symphalangus_syndactylus              57.640000                 57.640000
# Hylobates_moloch                      57.640000                 57.640000
# Nomascus_leucogenys                   57.640000                 57.640000
# Gorilla_gorilla_gorilla               57.640000                 57.640000
# Homo_sapiens                          57.640000                 57.640000
# Pan_paniscus                          57.640000                 57.640000
# Pan_troglodytes                       57.609647                 57.609647
# Pongo_pygmaeus                        57.640000                 57.640000
# Pongo_abelii                          57.640000                 57.640000
# Chlorocebus_sabaeus                   24.654320                 35.510000
# Papio_anubis                          20.908000                 35.510000
# Theropithecus_gelada                  20.908000                 35.510000
# Mandrillus_leucophaeus                20.908000                 35.510000
# Cercocebus_atys                       20.908000                 35.510000
# Macaca_thibetana_thibetana             8.994440                 35.510000
# Macaca_mulatta                         8.994440                 35.510000
# Macaca_fascicularis                    8.994440                 35.510000
# Macaca_nemestrina                      0.000000                 35.510000
# Trachypithecus_francoisi              35.510000                  0.000000
# Rhinopithecus_roxellana               35.510000                 20.217660
# Rhinopithecus_bieti                   35.510000                 20.217660
# Piliocolobus_tephrosceles             35.510000                 25.573100
# Colobus_angolensis_palliatus          35.510000                 25.573100
# Carlito_syrichta                     137.200000                137.200000
#
#                               Rhinopithecus_roxellana  Rhinopithecus_bieti  \
# Nycticebus_coucang                         147.509840           147.509840
# Otolemur_garnettii                         147.509840           147.509840
# Propithecus_coquereli                      147.509840           147.509840
# Microcebus_murinus                         147.509840           147.509840
# Lemur_catta                                147.509840           147.509840
# Eulemur_rufifrons                          147.509840           147.509840
# Aotus_nancymaae                             85.800000            85.800000
# Callithrix_jacchus                          85.800000            85.800000
# Cebus_imitator                              85.800000            85.800000
# Sapajus_apella                              85.800000            85.800000
# Saimiri_boliviensis                         85.696667            85.696667
# Symphalangus_syndactylus                    57.640000            57.640000
# Hylobates_moloch                            57.640000            57.640000
# Nomascus_leucogenys                         57.640000            57.640000
# Gorilla_gorilla_gorilla                     57.640000            57.640000
# Homo_sapiens                                57.640000            57.640000
# Pan_paniscus                                57.640000            57.640000
# Pan_troglodytes                             57.609647            57.609647
# Pongo_pygmaeus                              57.640000            57.640000
# Pongo_abelii                                57.640000            57.640000
# Chlorocebus_sabaeus                         35.510000            35.510000
# Papio_anubis                                35.510000            35.510000
# Theropithecus_gelada                        35.510000            35.510000
# Mandrillus_leucophaeus                      35.510000            35.510000
# Cercocebus_atys                             35.510000            35.510000
# Macaca_thibetana_thibetana                  35.510000            35.510000
# Macaca_mulatta                              35.510000            35.510000
# Macaca_fascicularis                         35.510000            35.510000
# Macaca_nemestrina                           35.510000            35.510000
# Trachypithecus_francoisi                    20.217660            20.217660
# Rhinopithecus_roxellana                      0.000000             4.380000
# Rhinopithecus_bieti                          4.380000             0.000000
# Piliocolobus_tephrosceles                   25.573100            25.573100
# Colobus_angolensis_palliatus                25.573100            25.573100
# Carlito_syrichta                           137.200000           137.200000
#
#                               Piliocolobus_tephrosceles  \
# Nycticebus_coucang                           147.509840
# Otolemur_garnettii                           147.509840
# Propithecus_coquereli                        147.509840
# Microcebus_murinus                           147.509840
# Lemur_catta                                  147.509840
# Eulemur_rufifrons                            147.509840
# Aotus_nancymaae                               85.800000
# Callithrix_jacchus                            85.800000
# Cebus_imitator                                85.800000
# Sapajus_apella                                85.800000
# Saimiri_boliviensis                           85.696667
# Symphalangus_syndactylus                      57.640000
# Hylobates_moloch                              57.640000
# Nomascus_leucogenys                           57.640000
# Gorilla_gorilla_gorilla                       57.640000
# Homo_sapiens                                  57.640000
# Pan_paniscus                                  57.640000
# Pan_troglodytes                               57.609647
# Pongo_pygmaeus                                57.640000
# Pongo_abelii                                  57.640000
# Chlorocebus_sabaeus                           35.510000
# Papio_anubis                                  35.510000
# Theropithecus_gelada                          35.510000
# Mandrillus_leucophaeus                        35.510000
# Cercocebus_atys                               35.510000
# Macaca_thibetana_thibetana                    35.510000
# Macaca_mulatta                                35.510000
# Macaca_fascicularis                           35.510000
# Macaca_nemestrina                             35.510000
# Trachypithecus_francoisi                      25.573100
# Rhinopithecus_roxellana                       25.573100
# Rhinopithecus_bieti                           25.573100
# Piliocolobus_tephrosceles                      0.000000
# Colobus_angolensis_palliatus                  20.710000
# Carlito_syrichta                             137.200000
#
#                               Colobus_angolensis_palliatus  Carlito_syrichta
# Nycticebus_coucang                              147.509840        147.509840
# Otolemur_garnettii                              147.509840        147.509840
# Propithecus_coquereli                           147.509840        147.509840
# Microcebus_murinus                              147.509840        147.509840
# Lemur_catta                                     147.509840        147.509840
# Eulemur_rufifrons                               147.509840        147.509840
# Aotus_nancymaae                                  85.800000        137.200000
# Callithrix_jacchus                               85.800000        137.200000
# Cebus_imitator                                   85.800000        137.200000
# Sapajus_apella                                   85.800000        137.200000
# Saimiri_boliviensis                              85.696667        137.096667
# Symphalangus_syndactylus                         57.640000        137.200000
# Hylobates_moloch                                 57.640000        137.200000
# Nomascus_leucogenys                              57.640000        137.200000
# Gorilla_gorilla_gorilla                          57.640000        137.200000
# Homo_sapiens                                     57.640000        137.200000
# Pan_paniscus                                     57.640000        137.200000
# Pan_troglodytes                                  57.609647        137.169647
# Pongo_pygmaeus                                   57.640000        137.200000
# Pongo_abelii                                     57.640000        137.200000
# Chlorocebus_sabaeus                              35.510000        137.200000
# Papio_anubis                                     35.510000        137.200000
# Theropithecus_gelada                             35.510000        137.200000
# Mandrillus_leucophaeus                           35.510000        137.200000
# Cercocebus_atys                                  35.510000        137.200000
# Macaca_thibetana_thibetana                       35.510000        137.200000
# Macaca_mulatta                                   35.510000        137.200000
# Macaca_fascicularis                              35.510000        137.200000
# Macaca_nemestrina                                35.510000        137.200000
# Trachypithecus_francoisi                         25.573100        137.200000
# Rhinopithecus_roxellana                          25.573100        137.200000
# Rhinopithecus_bieti                              25.573100        137.200000
# Piliocolobus_tephrosceles                        20.710000        137.200000
# Colobus_angolensis_palliatus                      0.000000        137.200000
# Carlito_syrichta                                137.200000          0.000000
#
# [35 rows x 35 columns]
# <Axes: >

# %%
print(specie_order)
# Out:
# ['Nycticebus coucang', 'Otolemur garnettii', 'Propithecus coquereli', 'Microcebus murinus', 'Lemur catta', 'Eulemur rufifrons', 'Aotus nancymaae', 'Callithrix jacchus', 'Cebus imitator', 'Sapajus apella', 'Saimiri boliviensis boliviensis', 'Symphalangus syndactylus', 'Hylobates moloch', 'Nomascus leucogenys', 'Gorilla gorilla gorilla', 'Homo sapiens', 'Pan paniscus', 'Pan troglodytes', 'Pongo pygmaeus', 'Pongo abelii', 'Chlorocebus sabaeus', 'Papio anubis', 'Theropithecus gelada', 'Mandrillus leucophaeus', 'Cercocebus atys', 'Macaca thibetana thibetana', 'Macaca mulatta', 'Macaca fascicularis', 'Macaca nemestrina', 'Trachypithecus francoisi', 'Rhinopithecus roxellana', 'Rhinopithecus bieti', 'Piliocolobus tephrosceles', 'Colobus angolensis palliatus', 'Carlito syrichta']

# %%
def create_df (df_table, path_to_df_dir) : 
    genid_species = dict(zip(df_table['genome_id'], df_table['specie_name']))
    genomes_list = []
    species_list = []
    df=[]
    for genome in os.scandir(path_to_df_dir): 
        genomes_list.append(genome.name)
        species_list.append(genid_species.get(genome.name))
    for i in range(len(genomes_list)): 
        path_dir= os.path.join(path_to_df_dir,genomes_list[i])
        df_stats_i = pd.read_csv(os.path.join(path_dir,'df_stats'))
        row = []
        for j in range(len(genomes_list)):
            path_dir= os.path.join(path_to_df_dir,genomes_list[j])
            df_stats_j = pd.read_csv(os.path.join(path_dir,'df_stats'))
            ks_score = scipy.stats.ks_2samp(df_stats_i['nb_exons'], df_stats_j['nb_exons'],nan_policy='omit')
            row.append(ks_score.statistic)
        df.append(row)

    df_ks_i = pd.DataFrame(df, columns=species_list, index=species_list)
    df_ks_i = df_ks_i.reindex(index=specie_order, columns=specie_order)
    print(species_list)
    return df_ks_i
df_ks_i = create_df(df_table, '/home/collot/stage/collot/out_stats/output_dataframes')
print(df_ks_i)
# Out:
# ['Piliocolobus tephrosceles', 'Nycticebus coucang', 'Rhinopithecus roxellana', 'Papio anubis', 'Saimiri boliviensis boliviensis', 'Lemur catta', 'Macaca nemestrina', 'Pan troglodytes', 'Hylobates moloch', 'Trachypithecus francoisi', 'Cebus imitator', 'Pongo abelii', 'Sapajus apella', 'Macaca thibetana thibetana', 'Macaca mulatta', 'Mandrillus leucophaeus', 'Colobus angolensis palliatus', 'Otolemur garnettii', 'Theropithecus gelada', 'Pongo pygmaeus', 'Cercocebus atys', 'Propithecus coquereli', 'Chlorocebus sabaeus', 'Macaca fascicularis', 'Symphalangus syndactylus', 'Nomascus leucogenys', 'Rhinopithecus bieti', 'Gorilla gorilla gorilla', 'Aotus nancymaae', 'Callithrix jacchus', 'Homo sapiens', 'Carlito syrichta', 'Microcebus murinus', 'Pan paniscus', 'Eulemur rufifrons']
#                                  Nycticebus coucang  Otolemur garnettii  \
# Nycticebus coucang                         0.000000            0.057513
# Otolemur garnettii                         0.057513            0.000000
# Propithecus coquereli                      0.066085            0.019064
# Microcebus murinus                         0.083585            0.062212
# Lemur catta                                0.063502            0.035303
# Eulemur rufifrons                          0.054962            0.029413
# Aotus nancymaae                            0.033851            0.033392
# Callithrix jacchus                         0.043707            0.068083
# Cebus imitator                             0.036775            0.024376
# Sapajus apella                             0.067887            0.054596
# Saimiri boliviensis boliviensis            0.043676            0.018107
# Symphalangus syndactylus                   0.072629            0.092356
# Hylobates moloch                           0.062158            0.040938
# Nomascus leucogenys                        0.087573            0.050090
# Gorilla gorilla gorilla                    0.055513            0.068032
# Homo sapiens                               0.114336            0.117277
# Pan paniscus                               0.045411            0.064009
# Pan troglodytes                            0.077268            0.100651
# Pongo pygmaeus                             0.066533            0.081343
# Pongo abelii                               0.063330            0.077507
# Chlorocebus sabaeus                        0.044162            0.039416
# Papio anubis                               0.071246            0.072604
# Theropithecus gelada                       0.083119            0.069494
# Mandrillus leucophaeus                     0.094340            0.053409
# Cercocebus atys                            0.086378            0.065171
# Macaca thibetana thibetana                 0.046155            0.047288
# Macaca mulatta                             0.077243            0.080581
# Macaca fascicularis                        0.047970            0.046004
# Macaca nemestrina                          0.086718            0.065615
# Trachypithecus francoisi                   0.048786            0.052228
# Rhinopithecus roxellana                    0.077380            0.047388
# Rhinopithecus bieti                        0.079441            0.021928
# Piliocolobus tephrosceles                  0.080354            0.027591
# Colobus angolensis palliatus               0.095720            0.053896
# Carlito syrichta                           0.071801            0.018868
#
#                                  Propithecus coquereli  Microcebus murinus  \
# Nycticebus coucang                            0.066085            0.083585
# Otolemur garnettii                            0.019064            0.062212
# Propithecus coquereli                         0.000000            0.078679
# Microcebus murinus                            0.078679            0.000000
# Lemur catta                                   0.053271            0.027035
# Eulemur rufifrons                             0.043342            0.036543
# Aotus nancymaae                               0.051153            0.051129
# Callithrix jacchus                            0.084629            0.054053
# Cebus imitator                                0.042177            0.056693
# Sapajus apella                                0.071726            0.021037
# Saimiri boliviensis boliviensis               0.034653            0.049032
# Symphalangus syndactylus                      0.109520            0.035854
# Hylobates moloch                              0.057829            0.035158
# Nomascus leucogenys                           0.066580            0.016871
# Gorilla gorilla gorilla                       0.085839            0.036454
# Homo sapiens                                  0.125847            0.056742
# Pan paniscus                                  0.079980            0.049318
# Pan troglodytes                               0.117592            0.049702
# Pongo pygmaeus                                0.099675            0.023967
# Pongo abelii                                  0.096052            0.028213
# Chlorocebus sabaeus                           0.055387            0.047252
# Papio anubis                                  0.089737            0.015144
# Theropithecus gelada                          0.078546            0.022810
# Mandrillus leucophaeus                        0.059602            0.047722
# Cercocebus atys                               0.083716            0.007890
# Macaca thibetana thibetana                    0.064766            0.044086
# Macaca mulatta                                0.097993            0.020297
# Macaca fascicularis                           0.064548            0.036897
# Macaca nemestrina                             0.082590            0.008231
# Trachypithecus francoisi                      0.068774            0.040662
# Rhinopithecus roxellana                       0.061458            0.017826
# Rhinopithecus bieti                           0.034705            0.045984
# Piliocolobus tephrosceles                     0.044273            0.035974
# Colobus angolensis palliatus                  0.062360            0.045780
# Carlito syrichta                              0.008721            0.073347
#
#                                  Lemur catta  Eulemur rufifrons  \
# Nycticebus coucang                  0.063502           0.054962
# Otolemur garnettii                  0.035303           0.029413
# Propithecus coquereli               0.053271           0.043342
# Microcebus murinus                  0.027035           0.036543
# Lemur catta                         0.000000           0.013502
# Eulemur rufifrons                   0.013502           0.000000
# Aotus nancymaae                     0.031046           0.022506
# Callithrix jacchus                  0.036245           0.048061
# Cebus imitator                      0.037840           0.031222
# Sapajus apella                      0.020514           0.032508
# Saimiri boliviensis boliviensis     0.030809           0.023151
# Symphalangus syndactylus            0.059690           0.071916
# Hylobates moloch                    0.017662           0.020499
# Nomascus leucogenys                 0.025840           0.036369
# Gorilla gorilla gorilla             0.034250           0.047592
# Homo sapiens                        0.081974           0.087863
# Pan paniscus                        0.030875           0.044083
# Pan troglodytes                     0.070364           0.081985
# Pongo pygmaeus                      0.047261           0.060510
# Pongo abelii                        0.043682           0.055653
# Chlorocebus sabaeus                 0.028583           0.020925
# Papio anubis                        0.038522           0.050121
# Theropithecus gelada                0.034191           0.040598
# Mandrillus leucophaeus              0.031894           0.039378
# Cercocebus atys                     0.031042           0.043369
# Macaca thibetana thibetana          0.024003           0.026235
# Macaca mulatta                      0.046499           0.056551
# Macaca fascicularis                 0.016815           0.025274
# Macaca nemestrina                   0.031533           0.043114
# Trachypithecus francoisi            0.020579           0.032109
# Rhinopithecus roxellana             0.015648           0.026177
# Rhinopithecus bieti                 0.021136           0.028238
# Piliocolobus tephrosceles           0.018622           0.029151
# Colobus angolensis palliatus        0.032348           0.042877
# Carlito syrichta                    0.049423           0.038220
#
#                                  Aotus nancymaae  Callithrix jacchus  \
# Nycticebus coucang                      0.033851            0.043707
# Otolemur garnettii                      0.033392            0.068083
# Propithecus coquereli                   0.051153            0.084629
# Microcebus murinus                      0.051129            0.054053
# Lemur catta                             0.031046            0.036245
# Eulemur rufifrons                       0.022506            0.048061
# Aotus nancymaae                         0.000000            0.035421
# Callithrix jacchus                      0.035421            0.000000
# Cebus imitator                          0.015277            0.046491
# Sapajus apella                          0.036651            0.034507
# Saimiri boliviensis boliviensis         0.016866            0.050732
# Symphalangus syndactylus                0.059990            0.034062
# Hylobates moloch                        0.030922            0.028756
# Nomascus leucogenys                     0.056337            0.056181
# Gorilla gorilla gorilla                 0.036227            0.021338
# Homo sapiens                            0.093722            0.084087
# Pan paniscus                            0.031082            0.011236
# Pan troglodytes                         0.068984            0.036986
# Pongo pygmaeus                          0.049829            0.032358
# Pongo abelii                            0.044900            0.029155
# Chlorocebus sabaeus                     0.012927            0.030289
# Papio anubis                            0.043113            0.041715
# Theropithecus gelada                    0.051883            0.051762
# Mandrillus leucophaeus                  0.061884            0.064809
# Cercocebus atys                         0.055142            0.056550
# Macaca thibetana thibetana              0.020598            0.026156
# Macaca mulatta                          0.052836            0.047214
# Macaca fascicularis                     0.016946            0.026431
# Macaca nemestrina                       0.055483            0.052543
# Trachypithecus francoisi                0.021248            0.019483
# Rhinopithecus roxellana                 0.046144            0.043396
# Rhinopithecus bieti                     0.048205            0.052119
# Piliocolobus tephrosceles               0.049119            0.046179
# Colobus angolensis palliatus            0.063264            0.066189
# Carlito syrichta                        0.049217            0.084553
#
#                                  Cebus imitator  Sapajus apella  ...  \
# Nycticebus coucang                     0.036775        0.067887  ...
# Otolemur garnettii                     0.024376        0.054596  ...
# Propithecus coquereli                  0.042177        0.071726  ...
# Microcebus murinus                     0.056693        0.021037  ...
# Lemur catta                            0.037840        0.020514  ...
# Eulemur rufifrons                      0.031222        0.032508  ...
# Aotus nancymaae                        0.015277        0.036651  ...
# Callithrix jacchus                     0.046491        0.034507  ...
# Cebus imitator                         0.000000        0.037718  ...
# Sapajus apella                         0.037718        0.000000  ...
# Saimiri boliviensis boliviensis        0.010011        0.039882  ...
# Symphalangus syndactylus               0.070081        0.042045  ...
# Hylobates moloch                       0.027049        0.017540  ...
# Nomascus leucogenys                    0.058353        0.022497  ...
# Gorilla gorilla gorilla                0.046563        0.016908  ...
# Homo sapiens                           0.107079        0.073104  ...
# Pan paniscus                           0.042512        0.029772  ...
# Pan troglodytes                        0.080414        0.052869  ...
# Pongo pygmaeus                         0.060165        0.028221  ...
# Pongo abelii                           0.054030        0.026363  ...
# Chlorocebus sabaeus                    0.018415        0.028461  ...
# Papio anubis                           0.053585        0.020162  ...
# Theropithecus gelada                   0.063040        0.028867  ...
# Mandrillus leucophaeus                 0.069288        0.045260  ...
# Cercocebus atys                        0.060760        0.025104  ...
# Macaca thibetana thibetana             0.032693        0.024540  ...
# Macaca mulatta                         0.065565        0.031590  ...
# Macaca fascicularis                    0.028770        0.020806  ...
# Macaca nemestrina                      0.057693        0.022037  ...
# Trachypithecus francoisi               0.031340        0.021115  ...
# Rhinopithecus roxellana                0.048302        0.015588  ...
# Rhinopithecus bieti                    0.042665        0.038872  ...
# Piliocolobus tephrosceles              0.043579        0.027773  ...
# Colobus angolensis palliatus           0.068361        0.041872  ...
# Carlito syrichta                       0.038592        0.067659  ...
#
#                                  Macaca thibetana thibetana  Macaca mulatta  \
# Nycticebus coucang                                 0.046155        0.077243
# Otolemur garnettii                                 0.047288        0.080581
# Propithecus coquereli                              0.064766        0.097993
# Microcebus murinus                                 0.044086        0.020297
# Lemur catta                                        0.024003        0.046499
# Eulemur rufifrons                                  0.026235        0.056551
# Aotus nancymaae                                    0.020598        0.052836
# Callithrix jacchus                                 0.026156        0.047214
# Cebus imitator                                     0.032693        0.065565
# Sapajus apella                                     0.024540        0.031590
# Saimiri boliviensis boliviensis                    0.032304        0.065866
# Symphalangus syndactylus                           0.049446        0.023549
# Hylobates moloch                                   0.016003        0.046794
# Nomascus leucogenys                                0.046213        0.034241
# Gorilla gorilla gorilla                            0.024006        0.030459
# Homo sapiens                                       0.075118        0.043343
# Pan paniscus                                       0.022075        0.043669
# Pan troglodytes                                    0.061652        0.038948
# Pongo pygmaeus                                     0.035622        0.017622
# Pongo abelii                                       0.033472        0.023406
# Chlorocebus sabaeus                                0.019750        0.051876
# Papio anubis                                       0.031748        0.013313
# Theropithecus gelada                               0.041795        0.037498
# Mandrillus leucophaeus                             0.054841        0.064595
# Cercocebus atys                                    0.046582        0.016097
# Macaca thibetana thibetana                         0.000000        0.035804
# Macaca mulatta                                     0.035804        0.000000
# Macaca fascicularis                                0.007189        0.037583
# Macaca nemestrina                                  0.042474        0.017240
# Trachypithecus francoisi                           0.010146        0.039671
# Rhinopithecus roxellana                            0.033428        0.038110
# Rhinopithecus bieti                                0.033286        0.064857
# Piliocolobus tephrosceles                          0.034199        0.054106
# Colobus angolensis palliatus                       0.056221        0.060811
# Carlito syrichta                                   0.060933        0.093644
#
#                                  Macaca fascicularis  Macaca nemestrina  \
# Nycticebus coucang                          0.047970           0.086718
# Otolemur garnettii                          0.046004           0.065615
# Propithecus coquereli                       0.064548           0.082590
# Microcebus murinus                          0.036897           0.008231
# Lemur catta                                 0.016815           0.031533
# Eulemur rufifrons                           0.025274           0.043114
# Aotus nancymaae                             0.016946           0.055483
# Callithrix jacchus                          0.026431           0.052543
# Cebus imitator                              0.028770           0.057693
# Sapajus apella                              0.020806           0.022037
# Saimiri boliviensis boliviensis             0.030262           0.050901
# Symphalangus syndactylus                    0.048963           0.032058
# Hylobates moloch                            0.015077           0.034946
# Nomascus leucogenys                         0.040491           0.021422
# Gorilla gorilla gorilla                     0.023747           0.034842
# Homo sapiens                                0.079097           0.058739
# Pan paniscus                                0.022261           0.047706
# Pan troglodytes                             0.060903           0.046415
# Pongo pygmaeus                              0.036416           0.021640
# Pongo abelii                                0.033657           0.026601
# Chlorocebus sabaeus                         0.017374           0.047347
# Papio anubis                                0.027677           0.017272
# Theropithecus gelada                        0.036037           0.026096
# Mandrillus leucophaeus                      0.047653           0.052838
# Cercocebus atys                             0.039394           0.004108
# Macaca thibetana thibetana                  0.007189           0.042474
# Macaca mulatta                              0.037583           0.017240
# Macaca fascicularis                         0.000000           0.039637
# Macaca nemestrina                           0.039637           0.000000
# Trachypithecus francoisi                    0.009772           0.039785
# Rhinopithecus roxellana                     0.030299           0.023145
# Rhinopithecus bieti                         0.032360           0.049891
# Piliocolobus tephrosceles                   0.033273           0.038317
# Colobus angolensis palliatus                0.049033           0.050896
# Carlito syrichta                            0.060692           0.078678
#
#                                  Trachypithecus francoisi  \
# Nycticebus coucang                               0.048786
# Otolemur garnettii                               0.052228
# Propithecus coquereli                            0.068774
# Microcebus murinus                               0.040662
# Lemur catta                                      0.020579
# Eulemur rufifrons                                0.032109
# Aotus nancymaae                                  0.021248
# Callithrix jacchus                               0.019483
# Cebus imitator                                   0.031340
# Sapajus apella                                   0.021115
# Saimiri boliviensis boliviensis                  0.035055
# Symphalangus syndactylus                         0.041487
# Hylobates moloch                                 0.013372
# Nomascus leucogenys                              0.042789
# Gorilla gorilla gorilla                          0.017972
# Homo sapiens                                     0.079307
# Pan paniscus                                     0.015366
# Pan troglodytes                                  0.054395
# Pongo pygmaeus                                   0.031573
# Pongo abelii                                     0.027322
# Chlorocebus sabaeus                              0.018263
# Papio anubis                                     0.030129
# Theropithecus gelada                             0.038935
# Mandrillus leucophaeus                           0.051417
# Cercocebus atys                                  0.043158
# Macaca thibetana thibetana                       0.010146
# Macaca mulatta                                   0.039671
# Macaca fascicularis                              0.009772
# Macaca nemestrina                                0.039785
# Trachypithecus francoisi                         0.000000
# Rhinopithecus roxellana                          0.030394
# Rhinopithecus bieti                              0.035996
# Piliocolobus tephrosceles                        0.031568
# Colobus angolensis palliatus                     0.052797
# Carlito syrichta                                 0.068699
#
#                                  Rhinopithecus roxellana  Rhinopithecus bieti  \
# Nycticebus coucang                              0.077380             0.079441
# Otolemur garnettii                              0.047388             0.021928
# Propithecus coquereli                           0.061458             0.034705
# Microcebus murinus                              0.017826             0.045984
# Lemur catta                                     0.015648             0.021136
# Eulemur rufifrons                               0.026177             0.028238
# Aotus nancymaae                                 0.046144             0.048205
# Callithrix jacchus                              0.043396             0.052119
# Cebus imitator                                  0.048302             0.042665
# Sapajus apella                                  0.015588             0.038872
# Saimiri boliviensis boliviensis                 0.039933             0.035765
# Symphalangus syndactylus                        0.051777             0.076245
# Hylobates moloch                                0.026785             0.024827
# Nomascus leucogenys                             0.012785             0.037023
# Gorilla gorilla gorilla                         0.027586             0.052017
# Homo sapiens                                    0.070986             0.102726
# Pan paniscus                                    0.038661             0.047898
# Pan troglodytes                                 0.065815             0.086945
# Pongo pygmaeus                                  0.039279             0.065619
# Pongo abelii                                    0.035769             0.061347
# Chlorocebus sabaeus                             0.037956             0.035279
# Papio anubis                                    0.030914             0.056880
# Theropithecus gelada                            0.023203             0.055321
# Mandrillus leucophaeus                          0.032778             0.045594
# Cercocebus atys                                 0.022968             0.049526
# Macaca thibetana thibetana                      0.033428             0.033286
# Macaca mulatta                                  0.038110             0.064857
# Macaca fascicularis                             0.030299             0.032360
# Macaca nemestrina                               0.023145             0.049891
# Trachypithecus francoisi                        0.030394             0.035996
# Rhinopithecus roxellana                         0.000000             0.033256
# Rhinopithecus bieti                             0.033256             0.000000
# Piliocolobus tephrosceles                       0.026101             0.011575
# Colobus angolensis palliatus                    0.030836             0.044080
# Carlito syrichta                                0.056280             0.033235
#
#                                  Piliocolobus tephrosceles  \
# Nycticebus coucang                                0.080354
# Otolemur garnettii                                0.027591
# Propithecus coquereli                             0.044273
# Microcebus murinus                                0.035974
# Lemur catta                                       0.018622
# Eulemur rufifrons                                 0.029151
# Aotus nancymaae                                   0.049119
# Callithrix jacchus                                0.046179
# Cebus imitator                                    0.043579
# Sapajus apella                                    0.027773
# Saimiri boliviensis boliviensis                   0.036679
# Symphalangus syndactylus                          0.066153
# Hylobates moloch                                  0.018196
# Nomascus leucogenys                               0.029259
# Gorilla gorilla gorilla                           0.041886
# Homo sapiens                                      0.092310
# Pan paniscus                                      0.039272
# Pan troglodytes                                   0.077783
# Pongo pygmaeus                                    0.055722
# Pongo abelii                                      0.052099
# Chlorocebus sabaeus                               0.036192
# Papio anubis                                      0.045784
# Theropithecus gelada                              0.046708
# Mandrillus leucophaeus                            0.040633
# Cercocebus atys                                   0.039763
# Macaca thibetana thibetana                        0.034199
# Macaca mulatta                                    0.054106
# Macaca fascicularis                               0.033273
# Macaca nemestrina                                 0.038317
# Trachypithecus francoisi                          0.031568
# Rhinopithecus roxellana                           0.026101
# Rhinopithecus bieti                               0.011575
# Piliocolobus tephrosceles                         0.000000
# Colobus angolensis palliatus                      0.039119
# Carlito syrichta                                  0.041849
#
#                                  Colobus angolensis palliatus  \
# Nycticebus coucang                                   0.095720
# Otolemur garnettii                                   0.053896
# Propithecus coquereli                                0.062360
# Microcebus murinus                                   0.045780
# Lemur catta                                          0.032348
# Eulemur rufifrons                                    0.042877
# Aotus nancymaae                                      0.063264
# Callithrix jacchus                                   0.066189
# Cebus imitator                                       0.068361
# Sapajus apella                                       0.041872
# Saimiri boliviensis boliviensis                      0.061167
# Symphalangus syndactylus                             0.080700
# Hylobates moloch                                     0.042663
# Nomascus leucogenys                                  0.030902
# Gorilla gorilla gorilla                              0.057211
# Homo sapiens                                         0.092048
# Pan paniscus                                         0.061454
# Pan troglodytes                                      0.093851
# Pongo pygmaeus                                       0.066117
# Pongo abelii                                         0.065096
# Chlorocebus sabaeus                                  0.059387
# Papio anubis                                         0.060473
# Theropithecus gelada                                 0.027499
# Mandrillus leucophaeus                               0.006104
# Cercocebus atys                                      0.050315
# Macaca thibetana thibetana                           0.056221
# Macaca mulatta                                       0.060811
# Macaca fascicularis                                  0.049033
# Macaca nemestrina                                    0.050896
# Trachypithecus francoisi                             0.052797
# Rhinopithecus roxellana                              0.030836
# Rhinopithecus bieti                                  0.044080
# Piliocolobus tephrosceles                            0.039119
# Colobus angolensis palliatus                         0.000000
# Carlito syrichta                                     0.054588
#
#                                  Carlito syrichta
# Nycticebus coucang                       0.071801
# Otolemur garnettii                       0.018868
# Propithecus coquereli                    0.008721
# Microcebus murinus                       0.073347
# Lemur catta                              0.049423
# Eulemur rufifrons                        0.038220
# Aotus nancymaae                          0.049217
# Callithrix jacchus                       0.084553
# Cebus imitator                           0.038592
# Sapajus apella                           0.067659
# Saimiri boliviensis boliviensis          0.034578
# Symphalangus syndactylus                 0.107999
# Hylobates moloch                         0.056401
# Nomascus leucogenys                      0.060917
# Gorilla gorilla gorilla                  0.082559
# Homo sapiens                             0.122164
# Pan paniscus                             0.080298
# Pan troglodytes                          0.118200
# Pongo pygmaeus                           0.095208
# Pongo abelii                             0.091991
# Chlorocebus sabaeus                      0.056201
# Papio anubis                             0.086008
# Theropithecus gelada                     0.070186
# Mandrillus leucophaeus                   0.051441
# Cercocebus atys                          0.078738
# Macaca thibetana thibetana               0.060933
# Macaca mulatta                           0.093644
# Macaca fascicularis                      0.060692
# Macaca nemestrina                        0.078678
# Trachypithecus francoisi                 0.068699
# Rhinopithecus roxellana                  0.056280
# Rhinopithecus bieti                      0.033235
# Piliocolobus tephrosceles                0.041849
# Colobus angolensis palliatus             0.054588
# Carlito syrichta                         0.000000
#
# [35 rows x 35 columns]

# %%
def create_df (df_table, path_to_df_dir) : 
    genid_species = dict(zip(df_table['genome_id'], df_table['specie_name']))
    genomes_list = []
    species_list = []
    df=[]
    for genome in os.scandir(path_to_df_dir): 
        genomes_list.append(genome.name)
        species_list.append(genid_species.get(genome.name))
    for i in range(len(genomes_list)): 
        path_dir= os.path.join(path_to_df_dir,genomes_list[i])
        df_stats_i = pd.read_csv(os.path.join(path_dir,'df_stats'))
        row = []
        for j in range(len(genomes_list)):
            path_dir= os.path.join(path_to_df_dir,genomes_list[j])
            df_stats_j = pd.read_csv(os.path.join(path_dir,'df_stats'))
            ks_score = scipy.stats.ks_2samp(df_stats_i['ratio_introns'], df_stats_j['ratio_introns'],nan_policy='omit')
            row.append(ks_score.pvalue)
        df.append(row)
    df_ks = pd.DataFrame(df, columns=species_list, index=species_list)
    df_ks = df_ks.reindex(index=specie_order, columns=specie_order)
    return df_ks
df_ks = create_df(df_table, '/home/collot/stage/collot/out_stats/output_dataframes')

# %%
sns.heatmap(df_ks, mask=mask1, cmap=sns.cm.rocket_r, vmax=.05, xticklabels=True, yticklabels=True )
sns.heatmap(df_ks_i, mask=mask1, vmax=.8, xticklabels=True, yticklabels=True )

# %%
mask1 = np.tril(np.ones_like(df_ks, dtype=bool))
mask2 = np.triu(np.ones_like(df_ks_i, dtype=bool))

fig, ax = plt.subplots(figsize=(11, 6))
sns.heatmap(df_ks, mask=mask1, cmap=sns.cm.rocket_r, vmax=.05 ,xticklabels=True, yticklabels=True )
sns.heatmap(distance_df, mask=mask2, cmap='grey',xticklabels=True, yticklabels=True)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(11, 6))
sns.heatmap(df_ks_i, mask=mask1, vmax=.2, xticklabels=True, yticklabels=True )
sns.heatmap(distance_df, mask=mask2, cmap='grey',xticklabels=True, yticklabels=True  )
# Out:
# <Axes: >
